# %%
Zahara Morris - Property Sales Transactions

Link - https://data.wprdc.org/dataset/real-estate-sales/resource/57b84145-f9eb-493b-a78f-9bc803413d99

The code below analyzes property sales for the year 2025. It collects the top Zipcodes and ranks them based on total sales value, and the highest average property value.
